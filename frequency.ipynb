# %% [markdown]
# <a href="https://colab.research.google.com/github/pavss/python2/blob/main/frequency.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-2f4cee88-e329-4ae1-ad1b-dff48f6001a1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2f4cee88-e329-4ae1-ad1b-dff48f6001a1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving olympics.csv to olympics.csv

# %%
import pandas as pd
import io
 
data = pd.read_csv(io.BytesIO(uploaded['olympics.csv']))
data.head(5)
# Out:
#     countries  ioc_code   summer_participations summer_gold  summer_silver  \
# 0  Afghanistan     (AFG)                     15           0              0
# 1      Algeria     (ALG)                     14           5              4
# 2    Argentina     (ARG)                     25          21             26
# 3      Armenia     (ARM)                      7           2              8
# 4  Australasia     (ANZ)                      2           3              4
#
#    summer_bronze summer_total  winter_participations  winter_gold  \
# 0              2            2                      0            0
# 1              8           17                      3            0
# 2             30           77                     20            0
# 3              8           18                      8            0
# 4              5           12                      0            0
#
#    winter_silver  winter_bronze  winter_total  total_participation total_gold  \
# ...

# %%
data.describe()
# Out:
#        summer_participations  summer_silver  summer_bronze  \
# count             156.000000     156.000000     156.000000
# mean               14.673077      34.782051      37.775641
# std                 7.432417      86.085726      83.157105
# min                 0.000000       0.000000       0.000000
# 25%                 9.750000       1.000000       1.000000
# 50%                15.000000       5.000000       6.000000
# 75%                19.000000      29.250000      31.250000
# max                29.000000     831.000000     738.000000
#
#        winter_participations  winter_gold  winter_silver  winter_bronze  \
# count             156.000000    156.00000     156.000000     156.000000
# mean                7.314103      7.50641       7.487179       7.442308
# std                 7.900024     22.23264      21.431808      20.126773
# min                 0.000000      0.00000       0.000000       0.000000
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
freq = pd.crosstab(index=data['summer_participations'],columns='Frequency')
freq
# Out:
# col_0                  Frequency
# summer_participations
# 0                              1
# 1                              4
# 2                              2
# 3                              6
# 4                              1
# 5                              3
# 6                              2
# 7                             15
# 8                              3
# 9                              2
# 10                            10
# 11                             7
# 12                             2
# 13                             9
# 14                             9
# 15                            14
# 16                             7
# 17                             8
# 18                             9
# 19                             4
# 20                             2
# 21                             3
# 22                             5
# 23                             4
# 24                             4
# 25                             4
# ...

# %%
sns.histplot(x='summer_participations',data=data)

# %%
freq = pd.crosstab(index=data['winter_participations'],columns='Frequency')
freq
# Out:
# col_0                  Frequency
# winter_participations
# 0                             43
# 1                             12
# 2                              9
# 3                              7
# 4                              7
# 5                              2
# 6                              6
# 7                              3
# 8                             16
# 9                              7
# 10                             3
# 11                             3
# 12                             4
# 13                             2
# 14                             1
# 15                             2
# 16                             1
# 17                             1
# 18                             3
# 19                             2
# 20                             4
# 21                             2
# 22                             4
# 24                            12

# %%
sns.histplot(x='winter_participations',data=data)

# %%
freq = pd.crosstab(index=data['total_participation'],columns='Frequency')
freq
# Out:
# col_0                Frequency
# total_participation
# 1                            3
# 2                            3
# 3                            4
# 4                            1
# 6                            2
# 7                            2
# 8                            3
# 9                            2
# 10                           7
# 11                           7
# 12                           2
# 13                           7
# 14                           7
# 15                          16
# 16                           7
# 17                           6
# 18                           7
# 19                           3
# 20                           2
# 21                           2
# 22                           5
# 23                           7
# 24                           3
# 25                           1
# 26                           1
# 27                           4
# 28                           2
# 29                           2
# ...

# %%
sns.histplot(x='total_participation',data=data)

# %%
freq = pd.crosstab(index=data['summer_silver'],columns='Frequency')
freq
# Out:
# col_0          Frequency
# summer_silver
# 0                     21
# 1                     31
# 2                     13
# 3                      6
# 4                      6
# 5                      5
# 6                      2
# 7                      4
# 8                      3
# 9                      4
# 10                     1
# 11                     5
# 12                     2
# 13                     2
# 14                     3
# 16                     1
# 21                     1
# 22                     1
# 23                     1
# 24                     1
# 26                     2
# 28                     1
# 29                     1
# 30                     1
# 33                     2
# 35                     1
# 36                     2
# 38                     1
# 42                     2
# 45                     1
# 49                     1
# 51                     1
# 54                     1
# 56                     1
# 67                     1
# ...

# %%
sns.histplot(x='summer_silver', data=data)

# %%
freq = pd.crosstab(index=data['winter_silver'],columns='Frequency')
freq
# Out:
# col_0          Frequency
# winter_silver
# 0                    111
# 1                      3
# 2                      8
# 3                      3
# 4                      1
# 5                      1
# 6                      4
# 7                      3
# 8                      2
# 11                     1
# 12                     1
# 15                     1
# 28                     1
# 30                     1
# 32                     1
# 36                     1
# 39                     1
# 42                     1
# 43                     1
# 47                     1
# 49                     1
# 51                     1
# 57                     1
# 65                     1
# 72                     1
# 88                     1
# 98                     1
# 122                    1
# 133                    1

# %%
sns.histplot(x='winter_silver', data=data)

# %%
freq = pd.crosstab(index=data['total_silver'],columns='Frequency')
freq
# Out:
# col_0         Frequency
# total_silver
# 0                    19
# 1                    30
# 2                    14
# 3                     7
# 4                     6
# 5                     5
# 6                     3
# 7                     4
# 8                     3
# 9                     2
# 10                    1
# 11                    5
# 12                    2
# 13                    1
# 14                    3
# 17                    2
# 18                    1
# 19                    1
# 23                    1
# 24                    1
# 25                    1
# 26                    2
# 32                    2
# 33                    1
# 35                    1
# 36                    1
# 37                    1
# 38                    1
# 40                    1
# 42                    2
# 44                    1
# 45                    1
# 57                    1
# 58                    1
# 60                    1
# 69                    1
# ...

# %%
sns.histplot(x='total_silver', data=data)

# %%
freq = pd.crosstab(index=data['summer_bronze'],columns='Frequency')
freq
# Out:
# col_0          Frequency
# summer_bronze
# 0                     23
# 1                     23
# 2                     14
# 3                      5
# 4                      8
# ...                  ...
# 247                    1
# 277                    1
# 296                    1
# 314                    1
# 738                    1
#
# [61 rows x 1 columns]

# %%
sns.histplot(x='summer_bronze', data=data)

# %%
freq = pd.crosstab(index=data['winter_bronze'],columns='Frequency')
freq
# Out:
# col_0          Frequency
# winter_bronze
# 0                    112
# 1                      4
# 2                      3
# 3                      2
# 4                      3
# 5                      2
# 6                      4
# 8                      1
# 9                      2
# 12                     1
# 13                     2
# 14                     1
# 15                     1
# 16                     1
# 17                     1
# 23                     1
# 31                     1
# 35                     2
# 45                     1
# 55                     1
# 56                     1
# 58                     1
# 59                     1
# 60                     1
# 65                     2
# 76                     1
# 91                     1
# 95                     1
# 124                    1

# %%
sns.histplot(x='winter_bronze', data=data)

# %%
freq = pd.crosstab(index=data['total_bronze'],columns = 'Frequency' )
freq
# Out:
# col_0         Frequency
# total_bronze
# 0                    21
# 1                    23
# 2                    14
# 3                     5
# 4                     8
# ...                 ...
# 312                   1
# 331                   1
# 332                   1
# 355                   1
# 833                   1
#
# [65 rows x 1 columns]

# %%
sns.histplot(x='total_bronze',data=data)
