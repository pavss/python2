# %% [markdown]
# <a href="https://colab.research.google.com/github/pavss/python2/blob/main/skewness.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Data used: Olympics data

# %%
from google.colab import files
 
 
uploaded = files.upload()
# Out:
#      <input type="file" id="files-66c64789-1115-4e36-ab6b-73166cbda37e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-66c64789-1115-4e36-ab6b-73166cbda37e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving olympics.csv to olympics.csv

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %matplotlib inline

# %%
import io
 
data= pd.read_csv(io.BytesIO(uploaded['olympics.csv']))
data.head(5)
# Out:
#     countries  ioc_code   summer_participations summer_gold  summer_silver  \
# 0  Afghanistan     (AFG)                     15           0              0
# 1      Algeria     (ALG)                     14           5              4
# 2    Argentina     (ARG)                     25          21             26
# 3      Armenia     (ARM)                      7           2              8
# 4  Australasia     (ANZ)                      2           3              4
#
#    summer_bronze summer_total  winter_participations  winter_gold  \
# 0              2            2                      0            0
# 1              8           17                      3            0
# 2             30           77                     20            0
# 3              8           18                      8            0
# 4              5           12                      0            0
#
#    winter_silver  winter_bronze  winter_total  total_participation total_gold  \
# ...

# %%
sns.heatmap(data.iloc[:,1:].corr(),annot = True)

# %%
sns.pairplot(data)

# %% [markdown]
# **Numeric variable**

# %%
sns.distplot(data['summer_participations'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
data['summer_participations'].skew()
# Out:
# 0.13266050382451533

# %% [markdown]
# Conclusion - The variable is normally distributed.

# %%
sns.distplot(data['summer_silver'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
data['summer_silver'].skew()
# Out:
# 5.966530527375056

# %% [markdown]
# Variable is rightly skewed

# %%
sns.distplot(data['summer_bronze'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
data['summer_bronze'].skew()
# Out:
# 4.867159649975352

# %% [markdown]
# Conclusion - The variable is rightly skewed

# %%
sns.distplot(data['winter_participations'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
data['winter_participations'].skew()
# Out:
# 0.9319566035667038

# %% [markdown]
# variable is rightly skewed

# %%
sns.distplot(data['winter_gold'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
data['winter_gold'].skew()
# Out:
# 3.827798258036098

# %% [markdown]
# Variable is rightly skewed

# %%
sns.distplot(data['winter_silver'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
data['winter_silver'].skew()
# Out:
# 3.7607286908430377

# %% [markdown]
# variable is rightly skewed

# %%
sns.distplot(data['winter_bronze'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
data['winter_bronze'].skew()
# Out:
# 3.3999562827775693

# %% [markdown]
# variable is rightly skewed

# %%
sns.distplot(data['winter_total'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
data['winter_total'].skew()
# Out:
# 3.63613766380761

# %% [markdown]
# variable is rightly skewed

# %%
sns.distplot(data['total_participation'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
data['total_participation'].skew()
# Out:
# 0.8308180431591303

# %% [markdown]
# Variable is rightly skewed

# %%
sns.distplot(data['total_silver'])

# %%
data['total_silver'].skew()
# Out:
# 5.508204953251363

# %% [markdown]
# Variable is rightly skewed

# %%
sns.distplot(data['total_bronze'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
data['total_bronze'].skew()
# Out:
# 4.439205476960166

# %% [markdown]
# Variable is rightly skewed

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   countries              156 non-null    object
#  1   ioc_code               156 non-null    object
#  2   summer_participations  156 non-null    int64
#  3   summer_gold            156 non-null    object
#  4   summer_silver          156 non-null    int64
#  5   summer_bronze          156 non-null    int64
#  6   summer_total           156 non-null    object
#  7   winter_participations  156 non-null    int64
#  8   winter_gold            156 non-null    int64
#  9   winter_silver          156 non-null    int64
#  10  winter_bronze          156 non-null    int64
#  11  winter_total           156 non-null    int64
#  12  total_participation    156 non-null    int64
#  13  total_gold             156 non-null    object
#  14  total_silver           156 non-null    int64
# ...

# %%
data.dtypes
# Out:
# countries                object
# ioc_code                 object
# summer_participations     int64
# summer_gold              object
# summer_silver             int64
# summer_bronze             int64
# summer_total             object
# winter_participations     int64
# winter_gold               int64
# winter_silver             int64
# winter_bronze             int64
# winter_total              int64
# total_participation       int64
# total_gold               object
# total_silver              int64
# total_bronze              int64
# total_total              object
# dtype: object
