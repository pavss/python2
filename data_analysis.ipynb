# %% [markdown]
# <a href="https://colab.research.google.com/github/pavss/python2/blob/main/data_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def flowers (x,y):
  return x + y

# %%
flowers(21,22)
# Out:
# 43

# %%
flowers('green','lilly')
# Out:
# 'greenlilly'

# %%
mylist = [458, 0.111,'rose','petals',True]
mylist
# Out:
# [458, 0.111, 'rose', 'petals', True]

# %%
mylist[2]
# Out:
# 'rose'

# %%
mylist[-2]
# Out:
# 'petals'

# %%
newlist = ['white', 'lilly', mylist]
newlist
# Out:
# ['white', 'lilly', [458, 0.111, 'rose', 'petals', True]]

# %%
list1 = [ 1,444,63556,223332, 'chottu', 'friend', 'meenu']
set1 = set(list1)
set1
# Out:
# {1, 223332, 444, 63556, 'chottu', 'friend', 'meenu'}

# %%
mytup = (24,55,67,89)
mytup
# Out:
# (24, 55, 67, 89)

# %%
mydict = {1:"colour",2:"red", False:True, 'rose':'green'}
mydict['rose']
# Out:
# 'green'

# %%
def mul(n1,n2):
  result = int(n1*n2)
  return result
mul(25,4)
# Out:
# 100

# %%
for x in mylist:
  print(x)
# Out:
# 458
# 0.111
# rose
# petals
# True

# %%
counter = len(mylist) -1
while(counter>=0):
  print(mylist[counter])
  counter = counter - 1
# Out:
# True
# petals
# rose
# 0.111
# 458

# %%
rand = [ str(n)+'red' for n in mylist]
rand
# Out:
# ['458red', '0.111red', 'rosered', 'petalsred', 'Truered']

# %% [markdown]
# https://raw.githubusercontent.com/a-forty-two/CGI-DPplusPy/main/breastcancer_data.csv

# %%
import pandas as pd

# %%
csv_url = 'https://raw.githubusercontent.com/a-forty-two/CGI-DPplusPy/main/breastcancer_data.csv'
data = pd.read_csv(csv_url)
data.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  symmetry_mean  \
# 0          0.11840           0.27760          0.3001         0.2419
# 1          0.08474           0.07864          0.0869         0.1812
# 2          0.10960           0.15990          0.1974         0.2069
# 3          0.14250           0.28390          0.2414         0.2597
# 4          0.10030           0.13280          0.1980         0.1809
#
#    fractal_dimension_mean
# 0                 0.07871
# 1                 0.05667
# ...

# %%
data
# Out:
#             id diagnosis  radius_mean  texture_mean  perimeter_mean  \
# 0       842302         M        17.99         10.38          122.80
# 1       842517         M        20.57         17.77          132.90
# 2     84300903         M        19.69         21.25          130.00
# 3     84348301         M        11.42         20.38           77.58
# 4     84358402         M        20.29         14.34          135.10
# ...        ...       ...          ...           ...             ...
# 1133     93316         M        21.56         22.39          142.00
# 1134     93317         M        20.13         28.25          131.20
# 1135     93318         M        16.60         28.08          108.30
# 1136     93319         M        20.60         29.33          140.10
# 1137     93320         B         7.76         24.54           47.92
#
#       area_mean  smoothness_mean  compactness_mean  concavity_mean  \
# 0        1001.0          0.11840           0.27760         0.30010
# ...

# %%
data.describe()
# Out:
#                  id  radius_mean  texture_mean  perimeter_mean    area_mean  \
# count  1.138000e+03  1138.000000   1138.000000     1138.000000  1138.000000
# mean   1.523243e+07    14.127292     19.289649       91.969033   654.889104
# std    8.965268e+07     3.522499      4.299144       24.288293   351.759340
# min    8.670000e+03     6.981000      9.710000       43.790000   143.500000
# 25%    9.299525e+04    11.700000     16.170000       75.170000   420.300000
# 50%    9.327950e+04    13.370000     18.840000       86.240000   551.100000
# 75%    9.060125e+05    15.780000     21.800000      104.100000   782.700000
# max    9.113205e+08    28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  symmetry_mean  \
# count      1138.000000       1138.000000     1138.000000    1138.000000
# mean          0.096360          0.104341        0.088799       0.181162
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1138 entries, 0 to 1137
# Data columns (total 11 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   id                      1138 non-null   int64
#  1   diagnosis               1138 non-null   object
#  2   radius_mean             1138 non-null   float64
#  3   texture_mean            1138 non-null   float64
#  4   perimeter_mean          1138 non-null   float64
#  5   area_mean               1138 non-null   float64
#  6   smoothness_mean         1138 non-null   float64
#  7   compactness_mean        1138 non-null   float64
#  8   concavity_mean          1138 non-null   float64
#  9   symmetry_mean           1138 non-null   float64
#  10  fractal_dimension_mean  1138 non-null   float64
# dtypes: float64(9), int64(1), object(1)
# memory usage: 97.9+ KB

# %%
data.columns
# Out:
# Index(['id', 'diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean',
#        'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'symmetry_mean', 'fractal_dimension_mean'],
#       dtype='object')

# %%
data.sort_values('diagnosis')
# Out:
#           id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 568    92751         B         7.76         24.54           47.92      181.0
# 693    92876         B        13.37         16.39           86.10      553.5
# 694    92877         B        13.85         17.21           88.44      588.7
# 697    92880         B        15.10         16.39           99.58      674.5
# 699    92882         B        12.19         13.29           79.08      455.8
# ..       ...       ...          ...           ...             ...        ...
# 749    92932         M        27.22         21.87          182.10     2250.0
# 746    92929         M        16.46         20.11          109.30      832.9
# 272  8910988         M        21.75         20.99          147.30     1491.0
# 741    92924         M        15.46         11.89          102.50      736.9
# 0     842302         M        17.99         10.38          122.80     1001.0
#
# ...

# %%
data.shape
# Out:
# (1138, 11)

# %%
data.size
# Out:
# 12518

# %%
len(data)
# Out:
# 1138

# %%
data['radius_mean'][:8]
# Out:
# 0    17.99
# 1    20.57
# 2    19.69
# 3    11.42
# 4    20.29
# 5    12.45
# 6    18.25
# 7    13.71
# Name: radius_mean, dtype: float64

# %%
data[['radius_mean','perimeter_mean','area_mean']][:10]
# Out:
#    radius_mean  perimeter_mean  area_mean
# 0        17.99          122.80     1001.0
# 1        20.57          132.90     1326.0
# 2        19.69          130.00     1203.0
# 3        11.42           77.58      386.1
# 4        20.29          135.10     1297.0
# 5        12.45           82.57      477.1
# 6        18.25          119.60     1040.0
# 7        13.71           90.20      577.9
# 8        13.00           87.50      519.8
# 9        12.46           83.97      475.9

# %% [markdown]
# **Data** **visualization**

# %%
import numpy as np
# %matplotlib inline

# %%
count=data['diagnosis'].value_counts()

# %%
count.plot(kind='bar')

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(data.radius_mean,50)
plt.show()

# %%
plt.hist(data.texture_mean,50)
plt.show()

# %%
plt.hist(data.perimeter_mean,50)
plt.show()

# %%
data.nunique()
# Out:
# id                        1138
# diagnosis                    2
# radius_mean                456
# texture_mean               479
# perimeter_mean             522
# area_mean                  539
# smoothness_mean            474
# compactness_mean           537
# concavity_mean             537
# symmetry_mean              432
# fractal_dimension_mean     499
# dtype: int64

# %%
data['diagnosis'].unique()
# Out:
# array(['M', 'B'], dtype=object)

# %%
import seaborn as sns

# %%
sns.catplot(x ="diagnosis",kind ="count", data = data)

# %%
sns.lineplot(data=data, x='perimeter_mean', y='area_mean');

# %%
sns.lineplot(data=data, x='radius_mean', y='area_mean');

# %%
sns.lineplot(data=data, x='symmetry_mean', y='fractal_dimension_mean');

# %%
sns.scatterplot(data=data, x='symmetry_mean', y='fractal_dimension_mean', 
                hue = 'diagnosis');

# %%
sns.scatterplot(data=data, x='compactness_mean', y='smoothness_mean', 
                hue = 'diagnosis');

# %%
sns.scatterplot(data=data, x='texture_mean', y='area_mean', 
                hue = 'diagnosis');

# %%
sns.distplot(x = data['texture_mean'], bins = 10)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(x = data['area_mean'], bins = 10)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.stripplot(y = data['perimeter_mean'], x = data['diagnosis'])

# %%
sns.stripplot(y = data['fractal_dimension_mean'], x = data['diagnosis'])

# %%
sns.swarmplot(y = data['concavity_mean'], x = data['diagnosis'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:1296: UserWarning: 9.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:1296: UserWarning: 56.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.heatmap(data.corr(), annot = True, cmap = 'viridis')

# %%
sns.violinplot(data=data, x='diagnosis', y='smoothness_mean')

# %%
sns.scatterplot(data=data, x='area_mean', y='smoothness_mean');

# %%
sns.pairplot(data)

# %%
sns.distplot(data['perimeter_mean'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
data['perimeter_mean'].skew()
# Out:
# 0.9893414848506061

# %% [markdown]
# variable is rightly skewed

# %%
sns.distplot(data['smoothness_mean'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
data['smoothness_mean'].skew()
# Out:
# 0.45572082693055094

# %% [markdown]
# Variable is normally distributed

# %%
sns.distplot(data['compactness_mean'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
data['compactness_mean'].skew()
# Out:
# 1.1885505286824685

# %% [markdown]
# Variable is rightly skewed

# %%
sns.distplot(data['concavity_mean'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
data['concavity_mean'].skew()
# Out:
# 1.3993283684546105

# %% [markdown]
# Variable is rightly skewed

# %%
sns.distplot(data['symmetry_mean'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
data['smoothness_mean'].skew()
# Out:
# 0.45572082693055094

# %% [markdown]
# Variable is normally distributed
